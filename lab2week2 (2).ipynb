# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randn(1000)

# %%
plt.hist(data, bins=30)
# Out:
# (array([ 1.,  2.,  5.,  6., 14., 10., 18., 41., 50., 61., 69., 68., 63.,
#         61., 95., 71., 79., 73., 61., 52., 33., 23., 17., 10.,  6.,  5.,
#          3.,  1.,  0.,  2.]),
#  array([-3.21468666, -2.99338219, -2.77207772, -2.55077325, -2.32946877,
#         -2.1081643 , -1.88685983, -1.66555536, -1.44425089, -1.22294642,
#         -1.00164195, -0.78033748, -0.55903301, -0.33772854, -0.11642407,
#          0.1048804 ,  0.32618487,  0.54748934,  0.76879381,  0.99009829,
#          1.21140276,  1.43270723,  1.6540117 ,  1.87531617,  2.09662064,
#          2.31792511,  2.53922958,  2.76053405,  2.98183852,  3.20314299,
#          3.42444746]),
#  <BarContainer object of 30 artists>)

# %%
plt.title("histogram")
plt.xlabel("Values")
plt.ylabel("Frequencies")
plt.show()

# %%
sizes=[30,25,15,10,5]
plt.pie(sizes)
plt.title("Pie Chart")
plt.show()
